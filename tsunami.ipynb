# %%
# Import libraries
# %matplotlib inline
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from google.colab import drive

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-44cb3b60-88a2-4b53-ae8b-e4885769f315" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-44cb3b60-88a2-4b53-ae8b-e4885769f315">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving call_functions.py to call_functions.py
# ...

# %%
from call_functions import Tsunami

# %%
TsunamiDF = pd.read_csv('/content/tsunami_dataset.csv')

# %%
TsunamiDF.head()
# Out:
#     ID  YEAR  MONTH   DAY  HOUR  MINUTE  LATITUDE  LONGITUDE  \
# 0   12  -330    NaN   NaN   NaN     NaN     40.00     25.000
# 1  481  1764    2.0  11.0   NaN     NaN     51.45     -2.583
# 2   71   859    NaN   NaN   NaN     NaN     36.08     36.250
# 3  186  1580    1.0   NaN   NaN     NaN     40.00    128.000
# 4    5 -1300    NaN   NaN   NaN     NaN     39.96     26.240
#
#                          LOCATION_NAME      COUNTRY  ...       CAUSE  \
# 0  E. SPORADES ISLANDS, AEGEAN ISLANDS       GREECE  ...  Earthquake
# 1                     BRISTOL, ENGLAND           UK  ...     Unknown
# 2                            SAMANDAGI       TURKEY  ...  Earthquake
# 3                           YELLOW SEA  NORTH KOREA  ...     Unknown
# 4                 IONIAN COASTS, TROAD       TURKEY  ...     Unknown
#
#           EVENT_VALIDITY EQ_MAGNITUDE  EQ_DEPTH  TS_INTENSITY  \
# 0  Very Doubtful Tsunami          7.0       NaN           NaN
# ...

# %%
# Object for class
cf = Tsunami(TsunamiDF)

# %%
cf.show_data_type(TsunamiDF)
# Out:
# ID                            int64
# YEAR                          int64
# MONTH                       float64
# DAY                         float64
# HOUR                        float64
# MINUTE                      float64
# LATITUDE                    float64
# LONGITUDE                   float64
# LOCATION_NAME                object
# COUNTRY                      object
# REGION                       object
# CAUSE                        object
# EVENT_VALIDITY               object
# EQ_MAGNITUDE                float64
# EQ_DEPTH                    float64
# TS_INTENSITY                float64
# DAMAGE_TOTAL_DESCRIPTION     object
# HOUSES_TOTAL_DESCRIPTION     object
# DEATHS_TOTAL_DESCRIPTION     object
# URL                          object
# COMMENTS                     object
# dtype: object

# %%
cf.show_column_names(TsunamiDF)
# Out:
# Index(['ID', 'YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'LATITUDE', 'LONGITUDE',
#        'LOCATION_NAME', 'COUNTRY', 'REGION', 'CAUSE', 'EVENT_VALIDITY',
#        'EQ_MAGNITUDE', 'EQ_DEPTH', 'TS_INTENSITY', 'DAMAGE_TOTAL_DESCRIPTION',
#        'HOUSES_TOTAL_DESCRIPTION', 'DEATHS_TOTAL_DESCRIPTION', 'URL',
#        'COMMENTS'],
#       dtype='object')

# %%
# check NULL
TsunamiDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2259 entries, 0 to 2258
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        2259 non-null   int64
#  1   YEAR                      2259 non-null   int64
#  2   MONTH                     2155 non-null   float64
#  3   DAY                       2082 non-null   float64
#  4   HOUR                      1308 non-null   float64
#  5   MINUTE                    1235 non-null   float64
#  6   LATITUDE                  2259 non-null   float64
#  7   LONGITUDE                 2259 non-null   float64
#  8   LOCATION_NAME             2250 non-null   object
#  9   COUNTRY                   2259 non-null   object
#  10  REGION                    2258 non-null   object
#  11  CAUSE                     2258 non-null   object
#  12  EVENT_VALIDITY            2259 non-null   object
# ...

# %%
df = cf.drop_null_values(TsunamiDF)
df
# Out:
#         ID  YEAR  MONTH   DAY  HOUR  MINUTE  LATITUDE  LONGITUDE  \
# 147    325  1678    6.0  18.0   1.0    45.0    -9.000    -79.000
# 161    194  1586    7.0  10.0   0.0    30.0   -12.300    -77.700
# 193    212  1604   11.0  24.0  18.0    30.0   -17.880    -70.940
# 247    424  1746   10.0  29.0   3.0    30.0   -11.996    -77.198
# 254    315  1674    2.0  17.0  11.0    30.0    -3.750    127.750
# ...    ...   ...    ...   ...   ...     ...       ...        ...
# 1504  2214  1992   12.0  12.0   5.0    29.0    -8.480    121.896
# 1533  2769  1783    2.0   5.0  12.0     0.0    38.300     15.967
# 1571  2916  1980   10.0  10.0  12.0    25.0    36.195      1.354
# 1771  3411  1905    9.0   8.0   1.0    43.0    38.670     16.070
# 2012  5456  1897   10.0  18.0  23.0    48.0    12.000    126.000
#
#             LOCATION_NAME      COUNTRY  ...                     CAUSE  \
# 147          CENTRAL PERU         PERU  ...                Earthquake
# ...

# %%
# check again if all the NULLs are dropped
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 121 entries, 147 to 2012
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        121 non-null    int64
#  1   YEAR                      121 non-null    int64
#  2   MONTH                     121 non-null    float64
#  3   DAY                       121 non-null    float64
#  4   HOUR                      121 non-null    float64
#  5   MINUTE                    121 non-null    float64
#  6   LATITUDE                  121 non-null    float64
#  7   LONGITUDE                 121 non-null    float64
#  8   LOCATION_NAME             121 non-null    object
#  9   COUNTRY                   121 non-null    object
#  10  REGION                    121 non-null    object
#  11  CAUSE                     121 non-null    object
#  12  EVENT_VALIDITY            121 non-null    object
# ...

# %%
cf.check_duplicates(df)
# Out:
# False

# %%
cf.plot_tsunami_country(df)

# %%
# countries with tsunami happened more than 15 times
cf.filter_tsunami_country(df,15)
# Out:
# JAPAN                True
# INDONESIA            True
# PERU                False
# CHILE               False
# PHILIPPINES         False
# GREECE              False
# PAPUA NEW GUINEA    False
# MEXICO              False
# USA                 False
# TAIWAN              False
# ITALY               False
# ECUADOR             False
# SAMOA               False
# RUSSIA              False
# SOLOMON ISLANDS     False
# ALGERIA             False
# PANAMA              False
# FIJI                False
# CHINA               False
# TURKEY              False
# MONTENEGRO          False
# UKRAINE             False
# NICARAGUA           False
# COLOMBIA            False
# Name: COUNTRY, dtype: bool

# %%
# function to check the number of times tsunami happeneed based year
cf.check_tsunami_year(df,1968)
# Out:
# There were 4 tsunami happened in 1968

# %%
# show dataframe after year 1991
cf.filter_df_by_year(df,1991)
# Out:
#         ID  YEAR  MONTH   DAY  HOUR  MINUTE  LATITUDE  LONGITUDE  \
# 1333  2403  2003    5.0  21.0  18.0    44.0    36.964      3.634
# 1334  2402  2003    1.0  22.0   2.0     6.0    18.770   -104.104
# 1336  2400  2002   10.0  10.0  10.0    50.0    -1.757    134.297
# 1338  2398  2002    9.0   8.0  18.0    44.0    -3.260    142.940
# 1355  2249  1995    7.0  30.0   5.0    11.0   -23.340    -70.294
# 1364  2223  1994    1.0  17.0  12.0    30.0    34.213   -118.537
# 1477  2261  1996    2.0  21.0  12.0    51.0    -9.593    -79.587
# 1478  2259  1996    1.0   1.0   8.0     5.0     0.729    119.931
# 1479  2252  1995   10.0   9.0  15.0    35.0    19.055   -104.205
# 1480  2245  1995    5.0  14.0  11.0    33.0    -8.452    125.049
# 1492  2234  1994   11.0  14.0  19.0    15.0    13.525    121.067
# 1496  2260  1996    2.0  17.0   5.0    59.0    -0.891    136.952
# 1497  2227  1994    6.0   2.0  18.0    17.0   -10.477    112.835
# ...

# %%
# number of tasunamis vs. causes
plt.figure(figsize=(25,4))
df.CAUSE.value_counts()[0:10].plot(kind='bar')
plt.grid()
plt.show()

# %%
cf.plot_total_death(df)

# %%
cf.check_outlier_intensity(df)

# %%
cf.check_outlier_hist(df)

# %%
cf.show_pair_plot(df)

# %%
df.corr()
# Out:
#                     ID      YEAR     MONTH       DAY      HOUR    MINUTE  \
# ID            1.000000  0.611886  0.011116 -0.081634  0.116759  0.042836
# YEAR          0.611886  1.000000 -0.060430 -0.057964  0.060848 -0.005463
# MONTH         0.011116 -0.060430  1.000000 -0.062453  0.102294  0.122477
# DAY          -0.081634 -0.057964 -0.062453  1.000000  0.011311  0.095368
# HOUR          0.116759  0.060848  0.102294  0.011311  1.000000  0.066691
# MINUTE        0.042836 -0.005463  0.122477  0.095368  0.066691  1.000000
# LATITUDE      0.138391  0.121606 -0.209262 -0.075668  0.067610  0.005422
# LONGITUDE     0.037429  0.074221 -0.105650 -0.029277  0.030381 -0.052238
# EQ_MAGNITUDE -0.127053 -0.161729  0.087291  0.007263 -0.054148  0.075377
# EQ_DEPTH     -0.259912 -0.186678  0.038705  0.087206 -0.069333  0.013208
# TS_INTENSITY -0.068994 -0.234522  0.173605  0.065567  0.015815  0.044201
#
#               LATITUDE  LONGITUDE  EQ_MAGNITUDE  EQ_DEPTH  TS_INTENSITY
# ...

# %%
cf.show_correlation(df)

# %%
cf.show_heat_map(df)

# %%
cf.show_scatter_plot(df)

# %%
cf.filter_correlation(df)
# Out:
#                     ID      YEAR  MONTH  DAY  HOUR  MINUTE  LATITUDE  \
# ID            1.000000  0.611886    NaN  NaN   NaN     NaN       NaN
# YEAR          0.611886  1.000000    NaN  NaN   NaN     NaN       NaN
# MONTH              NaN       NaN    1.0  NaN   NaN     NaN       NaN
# DAY                NaN       NaN    NaN  1.0   NaN     NaN       NaN
# HOUR               NaN       NaN    NaN  NaN   1.0     NaN       NaN
# MINUTE             NaN       NaN    NaN  NaN   NaN     1.0       NaN
# LATITUDE           NaN       NaN    NaN  NaN   NaN     NaN   1.00000
# LONGITUDE          NaN       NaN    NaN  NaN   NaN     NaN   0.24162
# EQ_MAGNITUDE       NaN       NaN    NaN  NaN   NaN     NaN       NaN
# EQ_DEPTH           NaN       NaN    NaN  NaN   NaN     NaN       NaN
# TS_INTENSITY       NaN       NaN    NaN  NaN   NaN     NaN       NaN
#
#               LONGITUDE  EQ_MAGNITUDE  EQ_DEPTH  TS_INTENSITY
# ID                  NaN           NaN       NaN           NaN
# ...

# %%
cf.filter_heat_map(df)

# %%
cf.plot_country_damage(df)
